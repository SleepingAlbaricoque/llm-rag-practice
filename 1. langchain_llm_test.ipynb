# %%
# %pip install langchain-openai python-dotenv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 1.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 401.8 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 501.4/501.4 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 3.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 2.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.7/345.7 kB 2.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 3.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.9/362.9 kB 3.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 3.4 MB/s eta 0:00:00
# ...

# %%
from dotenv import load_dotenv

load_dotenv() # .env 파일에서 환경변수 불러옴
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '인프런에는 다양한 분야의 강의들이 있습니다. 예를 들어 프로그래밍, 디자인, 비즈니스, 마케팅, 외국어, 취업 등 다양한 주제의 강의가 있습니다. 또한 신규 강의뿐만 아니라 인기 있는 강의나 최신 트렌드에 관련된 강의도 제공되고 있습니다. 원하는 분야나 주제에 맞춰서 강의를 선택하여 수강할 수 있습니다. 인프런의 강의에 대한 자세한 정보는 인프런 웹사이트를 방문하여 확인하실 수 있습니다.'
